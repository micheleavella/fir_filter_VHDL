# %% [markdown]
# # FIR FILTER DI MERDA

# %% [markdown]
# ![Fir Filter](https://surf-vhdl.com/wp/wp-content/uploads/2015/11/fir_filter4_architecture.jpg)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from bitstring import Bits
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-98dfceedd230> in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from tqdm import tqdm
#       4 from bitstring import Bits
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
# !conda install tqdm
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/michele/anaconda3/envs/mag
#
#   added / updated specs:
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.59.0                |     pyhd3eb1b0_1          93 KB
#     ------------------------------------------------------------
#                                            Total:          93 KB
#
# The following NEW packages will be INSTALLED:
#
#   tqdm               pkgs/main/noarch::tqdm-4.59.0-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.1.19-h06a4308_1
#
# ...

# %%
class fir_filter:     
    def __init__(self, coeff):
        self.c = np.array(coeff)
        self.x = np.zeros(len(coeff))
    def status(self):
        print('Coeff: ',self.c)
        print('x stored: ',self.x)
    def run(self,x):
        self.x=np.append(x,self.x)[:-1]
        return np.sum(self.x*self.c)
    def reset(self):
        self.x = np.zeros(len(self.c))


def cut_output(n):
    b = Bits(int=n, length=19)
    c = Bits(bin=b.bin[:8])
    return c.bin,c.int

# %%
c=[245, 254, 254, 245]

ff=fir_filter(c)
ff.status()
# Out:
# Coeff:  [245 254 254 245]
# x stored:  [0. 0. 0. 0.]

# %% [markdown]
# ## Filter example

# %%
#input data

data=-100*np.sin(np.linspace(0,20,30))

ff.reset()
l=[]
for i in data:
    l.append(ff.run(i))

print('Output: ')
for n in l:
    print(n)

print('Real Output: ')
for n in l:
    print(cut_output(int(n)))
# Out:
# Output:
# 0.0
# -15588.644338295528
# -40213.48991362224
# -62619.281446178065
# -71992.3805472797
# -48459.98918422278
# -2778.0356053777214
# 44173.672125600366
# 70934.960594901
# 65274.0725548686
# 29778.424840505908
# -19328.019838452426
# -59600.22445408097
# -72631.00987330574
# -52464.40711589282
# -8317.946560528882
# 39630.390098225085
# 69464.90118884669
# 67549.15445652872
# 34758.77847964042
# -13918.760070743665
# -56234.46389224306
# -72847.13356906602
# -56163.631612504105
# -13809.470755531658
# 34856.57206459934
# 67590.75388825066
# 69431.29265373862
# 39536.9350181918
# -8428.53275891746
# Real Output:
# ('00000000', 0)
# ('11111000', -8)
# ('11101100', -20)
# ('11100001', -31)
# ('11011100', -36)
# ('11101000', -24)
# ('11111110', -2)
# ('00010101', 21)
# ('00100010', 34)
# ('00011111', 31)
# ('00001110', 14)
# ('11110110', -10)
# ('11100010', -30)
# ('11011100', -36)
# ('11100110', -26)
# ('11111011', -5)
# ('00010011', 19)
# ('00100001', 33)
# ('00100000', 32)
# ...

# %%
np.random.seed(1234)

x=70*(np.sin(np.linspace(0,20,100))+0.3*(np.random.randint(-1,1,100)))
#x=50+20*(np.sin(np.linspace(0,20,100)))
x=x.astype(int)
print(x)
l=[]
ff.reset()
for i in tqdm(x) :
    ou=cut_output(int(ff.run(i)))
    l.append(ou[1])
l=np.array(l)
print(l)
plt.figure(figsize=(10,5))
plt.plot(l,label='out')
plt.plot(x,label='in')
plt.legend()
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 14125.09it/s]
# [  0  14   6  39  29  38  44  69  69  67  63  55  25  13  21 -13 -27 -41
#  -54 -65 -75 -83 -88 -90 -69 -87 -60 -51 -62 -49 -15 -22  -8  26  17  49
#   37  44  47  69  68  63  35  47  35   1   9 -25 -18 -52 -43 -53 -61 -67
#  -90 -69 -87 -60 -52 -63 -51 -16 -23  -9  24  37  48  36  43  47  69  68
#   64  57  48  36  24 -10  -3 -38 -30 -63 -52 -82 -87 -90 -90 -87 -82 -74
#  -64 -31 -18  -4 -11  23  15  26  56  63]
# [  0   1   2   7  10  13  18  21  26  30  32  30  25  19  13   5  -1  -8
#  -17 -23 -29 -34 -38 -41 -41 -41 -38 -33 -32 -28 -22 -18 -12  -3   1  10
#   15  17  21  23  27  30  28  25  21  14  11   2  -5 -11 -17 -21 -26 -28
#  -33 -36 -39 -38 -33 -32 -28 -23 -19 -13  -4   3  12  17  19  21  23  27
#   30  31  28  24  20  11   5  -4 -10 -17 -23 -28 -35 -38 -43 -44 -43 -41
#  -38 -31 -23 -15  -8  -2   2   6  14  19]

# %%
print(l[:4])
print(x[:4])
# Out:
# [12250. 25930. 40381. 55389.]
# [50 54 57 61]

# %% [markdown]
# ## TEST

# %%
coeff=np.array([-0.00531481, -0.01466647, -0.01916468, -0.01644422, -0.00668637,
        0.0071475 ,  0.0200985 ,  0.02683056,  0.02359389,  0.00987035,
       -0.01090934, -0.03192114, -0.04471759, -0.04174303, -0.0188434 ,
        0.02303083,  0.07752277,  0.13415278,  0.18088646,  0.20727744,
        0.20727744,  0.18088646,  0.13415278,  0.07752277,  0.02303083,
       -0.0188434 , -0.04174303, -0.04471759, -0.03192114, -0.01090934,
        0.00987035,  0.02359389,  0.02683056,  0.0200985 ,  0.0071475 ,
       -0.00668637, -0.01644422, -0.01916468, -0.01466647, -0.00531481])
#coeff=coeff/np.sum(coeff)

print(coeff)
ff=fir_filter(coeff)
ff.stampa()
# Out:
# [-0.00531481 -0.01466647 -0.01916468 -0.01644422 -0.00668637  0.0071475
#   0.0200985   0.02683056  0.02359389  0.00987035 -0.01090934 -0.03192114
#  -0.04471759 -0.04174303 -0.0188434   0.02303083  0.07752277  0.13415278
#   0.18088646  0.20727744  0.20727744  0.18088646  0.13415278  0.07752277
#   0.02303083 -0.0188434  -0.04174303 -0.04471759 -0.03192114 -0.01090934
#   0.00987035  0.02359389  0.02683056  0.0200985   0.0071475  -0.00668637
#  -0.01644422 -0.01916468 -0.01466647 -0.00531481]
# Coeff:  [-0.00531481 -0.01466647 -0.01916468 -0.01644422 -0.00668637  0.0071475
#   0.0200985   0.02683056  0.02359389  0.00987035 -0.01090934 -0.03192114
#  -0.04471759 -0.04174303 -0.0188434   0.02303083  0.07752277  0.13415278
#   0.18088646  0.20727744  0.20727744  0.18088646  0.13415278  0.07752277
#   0.02303083 -0.0188434  -0.04174303 -0.04471759 -0.03192114 -0.01090934
#   0.00987035  0.02359389  0.02683056  0.0200985   0.0071475  -0.00668637
# ...

# %%
x=20*(np.sin(np.linspace(0,20,50))+0.3*(np.random.randint(-1,1,50)))
x=x.astype(int)
l=[]
ff.reset()
for i in tqdm(x) :
    l.append(ff.run(i))
l=np.array(l)
plt.figure(figsize=(10,5))
plt.plot(l,label='out')
plt.plot(x,label='in')
plt.legend()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 22367.24it/s]

# %%
plt.plot(x)

# %%
f=[i for i in np.arange(1,100,0.01)]
L=[]
for freq in tqdm(f):
    x=np.sin(np.linspace(0,freq,100))
    l=[]
    ff.reset()
    for i in (x) :
        l.append(ff.run(i))
    l=np.array(l)
    L.append(np.mean(l**2)/np.mean(x**2))
    #L.append(np.max(l)/np.max(x))
plt.plot(f,L)
# Out:
# 100%|██████████| 9900/9900 [00:23<00:00, 425.28it/s]

# %%
x=np.sin(np.linspace(0,300,1000))
plt.plot(x,label='in')
plt.legend()

# %%
np.linspace(0,300,100)
# Out:
# array([  0.        ,   3.03030303,   6.06060606,   9.09090909,
#         12.12121212,  15.15151515,  18.18181818,  21.21212121,
#         24.24242424,  27.27272727,  30.3030303 ,  33.33333333,
#         36.36363636,  39.39393939,  42.42424242,  45.45454545,
#         48.48484848,  51.51515152,  54.54545455,  57.57575758,
#         60.60606061,  63.63636364,  66.66666667,  69.6969697 ,
#         72.72727273,  75.75757576,  78.78787879,  81.81818182,
#         84.84848485,  87.87878788,  90.90909091,  93.93939394,
#         96.96969697, 100.        , 103.03030303, 106.06060606,
#        109.09090909, 112.12121212, 115.15151515, 118.18181818,
#        121.21212121, 124.24242424, 127.27272727, 130.3030303 ,
#        133.33333333, 136.36363636, 139.39393939, 142.42424242,
#        145.45454545, 148.48484848, 151.51515152, 154.54545455,
#        157.57575758, 160.60606061, 163.63636364, 166.66666667,
#        169.6969697 , 172.72727273, 175.75757576, 178.78787879,
# ...

# %%
A=np.array([1,2,3,4])
A[:-1]
# Out:
# array([1, 2, 3])
